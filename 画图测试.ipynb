# %%
import sys, pathlib
# 把 tools 的绝对路径插到最前面
sys.path.insert(0, str(pathlib.Path('__file__').resolve().parent.parent / 'Quant_base'))

# %%
import Drawpic
# from Drawpic import *
import CLbasement
import Basement

# %%
import os
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# # 读取本地数据

# %%
# codefile = 'SZ.300316.csv'

# daydatapath = r'E:\python_vm\quant_code\data\A股\天粒度'
# dayfilepath = daydatapath + '\\' + codefile
# df_day = Basement.read_data_local(dayfilepath)

# min60datapath = r'E:\python_vm\quant_code\data\A股\60min粒度'
# min60filepath = min60datapath + '\\' + codefile
# df_60min = Basement.read_data_local(min60filepath)

# min30datapath = r'E:\python_vm\quant_code\data\A股\30min粒度'
# min30filepath = min30datapath + '\\' + codefile
# df_30min = Basement.read_data_local(min30filepath)

# %%
codefile = 'SZ.300750.csv'

daydatapath = r'F:\study\stock_related\2020_2025data\A股\天粒度'
dayfilepath = daydatapath + '\\' + codefile
df_day = Basement.read_data_local(dayfilepath)

# %% [markdown]
# # 画图

# %%
grid = Drawpic.generate_pic_by_df(df_day,[],[5,10,20])
grid.load_javascript()

# %%
grid.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="61e67671ebb94bc4a0a4cdaf41973fb7" class="chart-container" style="width:900px; height:500px; "></div>
#     <script>
#         var chart_61e67671ebb94bc4a0a4cdaf41973fb7 = echarts.init(
#             document.getElementById('61e67671ebb94bc4a0a4cdaf41973fb7'), 'white', {renderer: 'canvas'});
#         var option_61e67671ebb94bc4a0a4cdaf41973fb7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
# ...
